# %% [markdown]
# <a href="https://colab.research.google.com/github/jusnelda/i2dl_colab/blob/master/exercise_3/1_segmentation_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/My\ Drive/i2dl/
# Out:
# /content/drive/My Drive/i2dl

# %%
# !git clone https://github.com/jusnelda/i2dl_colab.git
# %cd /content/drive/My Drive/i2dl/i2dl_colab/exercise_3
# Out:
# fatal: destination path 'i2dl_colab' already exists and is not an empty directory.
# /content/drive/My Drive/i2dl/i2dl_colab/exercise_3

# %% [markdown]
# Semantic Segmentation
# ============
#
# In this exercise you are going to work on a computer vision task called semantic segmentation. In comparison to image classification the goal is not to classify an entire image but each of its pixels separately. This implies that the  output of the network is not a single scalar but a segmentation with the same shape as the input image. Think about why you should rather use convolutional than fully-connected layers for this task!
#
# Since we already introduced the basics of PyTorch and how to train a NN we leave the model design and architecture as well as the training up to you. We only provide you with the train, validation and test dataset and recommend you to look for inspirational, existing PyTorch implementations. Due to the fairly small size of the segmentation dataset you should not train a model from scratch but consider to (at least partially) finetune weights of an already exsisting model.
#
# The infamous  [Fully Convolutional Networks for Semantic Segmentation](https://people.eecs.berkeley.edu/~jonlong/long_shelhamer_fcn.pdf) paper might help you with finding a suitable segmentation model and architecture.
#
# <img src="https://camo.githubusercontent.com/d10b897e15344334e449104a824aff6c29125dc2/687474703a2f2f63616c76696e2e696e662e65642e61632e756b2f77702d636f6e74656e742f75706c6f6164732f646174612f636f636f7374756666646174617365742f636f636f73747566662d6578616d706c65732e706e67">

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import torch

from exercise_code.data_utils import SegmentationData, label_img_to_rgb

#torch.set_default_tensor_type('torch.FloatTensor')
#set up default cuda device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# MSRC-v2 Segmentation Dataset
# ================
#
# Make yourself familiar with the segmentation dataset and how we implemented the `SegmentationData` class in `exercise_code/data_utils.py`. Furthermore have a look at the labels described in `data/segmentation_data/info.html`. Especially note the label `unlabeled`. Pixels with the label `unlabeled` should neither be considered in your loss nor in the accuracy of your segmentation.

# %%
train_data = SegmentationData(image_paths_file='../../datasets/segmentation_data/train.txt')
#/content/drive/My Drive/i2dl/datasets
val_data = SegmentationData(image_paths_file='../../datasets/segmentation_data/val.txt')

# %%
print("Train size: %i" % len(train_data))
print("Validation size: %i" % len(val_data))
print("Img size: ", train_data[0][0].size())
print("Segmentation size: ", train_data[0][1].size())

num_example_imgs = 3
plt.figure(figsize=(10, 5 * num_example_imgs))
for i, (img, target) in enumerate(train_data[:num_example_imgs]):
    # img
    plt.subplot(num_example_imgs, 2, i * 2 + 1)
    plt.imshow(img.numpy().transpose(1,2,0))
    plt.axis('off')
    if i == 0:
        plt.title("Input image")
    
    # target
    plt.subplot(num_example_imgs, 2, i * 2 + 2)
    plt.imshow(label_img_to_rgb(target.numpy()))
    plt.axis('off')
    if i == 0:
        plt.title("Target image")
plt.show()
# Out:
# Train size: 276
# Validation size: 59
# Img size:  torch.Size([3, 240, 240])
# Segmentation size:  torch.Size([240, 240])

# %% [markdown]
# Design and Train your Network
# ==========
#
# Implement your network architecture in `exercise_code/classifiers/segmentation_nn.py` and adapt your `Solver` to process segmentation labels. To compensate for the dimension reduction of a typical convolution layer, you should probably include a `nn.Upsample` layer near the end of your network. Also remember to consider finetuning a model instead of training it from scratch.
#
# Up until now we only used the default loss function (`nn.CrossEntropyLoss`) of our `Solver` class. However, in order to ignore the `unlabeled` pixels for the computation of our loss, we have to use a customized version of the loss for the initializtation of the `Solver` class. The `ignore_index` argument of the loss can be used to filter the `unlabeled` pixels and computes the loss only over remaining pixels.
#
# Step by step:
# 1. Initialize training and validation data loaders.
# 2. Design and initialize a convolutional neural network architecture that has input (N, C, H, W) and output (N, num_classes, H, W) and is based on an already pretrained network.
# 3. Initialize a solver with a loss function that considers the `unlabeled` pixels.
# 4. Adjust the logging of your solver to account for the `unlabeled` pixels.
# 5. Train a segmentation model.

# %%
# !git pull
# Out:
# Already up to date.

# %%
from exercise_code.segmentation_nn import SegmentationNN
from exercise_code.solver import Solver
import torch.nn.functional as F

# train_loader = torch.utils.data.DataLoader(train_data, batch_size=10, shuffle=True, num_workers=0)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=1, shuffle=True, num_workers=0)
val_loader = torch.utils.data.DataLoader(val_data, batch_size=1, shuffle=False, num_workers=0)
model = SegmentationNN()
model.to(device)
solver = Solver(optim_args={"lr": 1e-4, "weight_decay": 0.001},
                loss_func=torch.nn.CrossEntropyLoss(ignore_index=-1, reduction='mean'))
solver.train(model, train_loader, val_loader, log_nth=5, num_epochs=5)
# Out:
# START TRAIN.
# [Iteration 0/1380]    TRAIN loss: 3.5926
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:2404: UserWarning: nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.
#   warnings.warn("nn.functional.upsample is deprecated. Use nn.functional.interpolate instead.")
# [Iteration 5/1380]    TRAIN loss: 3.1967
# [Iteration 10/1380]    TRAIN loss: 2.7174
# [Iteration 15/1380]    TRAIN loss: 3.1521
# [Iteration 20/1380]    TRAIN loss: 3.4989
# [Iteration 25/1380]    TRAIN loss: 5.2224
# [Iteration 30/1380]    TRAIN loss: 3.4767
# [Iteration 35/1380]    TRAIN loss: 2.1807
# [Iteration 40/1380]    TRAIN loss: 2.5223
# [Iteration 45/1380]    TRAIN loss: 2.9306
# [Iteration 50/1380]    TRAIN loss: 3.6300
# [Iteration 55/1380]    TRAIN loss: 3.4780
# [Iteration 60/1380]    TRAIN loss: 3.2649
# [Iteration 65/1380]    TRAIN loss: 2.8298
# [Iteration 70/1380]    TRAIN loss: 2.9079
# [Iteration 75/1380]    TRAIN loss: 2.2687
# [Iteration 80/1380]    TRAIN loss: 2.9853
# [Iteration 85/1380]    TRAIN loss: 3.2008
# [Iteration 90/1380]    TRAIN loss: 2.8512
# [Iteration 95/1380]    TRAIN loss: 2.0865
# [Iteration 100/1380]    TRAIN loss: 1.9451
# [Iteration 105/1380]    TRAIN loss: 3.4899
# [Iteration 110/1380]    TRAIN loss: 2.9790
# [Iteration 115/1380]    TRAIN loss: 2.9114
# [Iteration 120/1380]    TRAIN loss: 2.4257
# [Iteration 125/1380]    TRAIN loss: 3.0712
# [Iteration 130/1380]    TRAIN loss: 4.0153
# [Iteration 135/1380]    TRAIN loss: 4.2113
# [Iteration 140/1380]    TRAIN loss: 2.7232
# [Iteration 145/1380]    TRAIN loss: 3.2462
# [Iteration 150/1380]    TRAIN loss: 2.9924
# [Iteration 155/1380]    TRAIN loss: 2.7549
# [Iteration 160/1380]    TRAIN loss: 3.8438
# [Iteration 165/1380]    TRAIN loss: 2.9250
# [Iteration 170/1380]    TRAIN loss: 3.0516
# [Iteration 175/1380]    TRAIN loss: 3.4227
# [Iteration 180/1380]    TRAIN loss: 3.6418
# [Iteration 185/1380]    TRAIN loss: 2.7473
# [Iteration 190/1380]    TRAIN loss: 2.9700
# [Iteration 195/1380]    TRAIN loss: 3.9651
# [Iteration 200/1380]    TRAIN loss: 4.0961
# [Iteration 205/1380]    TRAIN loss: 3.0174
# [Iteration 210/1380]    TRAIN loss: 2.2760
# [Iteration 215/1380]    TRAIN loss: 1.8871
# [Iteration 220/1380]    TRAIN loss: 2.5057
# [Iteration 225/1380]    TRAIN loss: 3.0038
# [Iteration 230/1380]    TRAIN loss: 3.3502
# [Iteration 235/1380]    TRAIN loss: 2.2978
# [Iteration 240/1380]    TRAIN loss: 3.4182
# [Iteration 245/1380]    TRAIN loss: 2.9951
# [Iteration 250/1380]    TRAIN loss: 2.7309
# [Iteration 255/1380]    TRAIN loss: 3.8804
# [Iteration 260/1380]    TRAIN loss: 2.5348
# [Iteration 265/1380]    TRAIN loss: 2.7755
# [Iteration 270/1380]    TRAIN loss: 4.2402
# [Iteration 275/1380]    TRAIN loss: 2.7519
# [Epoch 0/4     TRAIN acc/loss: 4514.3152/2.7519]
# [Epoch 0/4     VAL acc/loss: 25167.8475/3.7042]
# ----------
# [Iteration 0/1380]    TRAIN loss: 2.7788
# [Iteration 5/1380]    TRAIN loss: 2.4393
# [Iteration 10/1380]    TRAIN loss: 2.2809
# [Iteration 15/1380]    TRAIN loss: 3.2417
# [Iteration 20/1380]    TRAIN loss: 2.5934
# [Iteration 25/1380]    TRAIN loss: 2.7680
# [Iteration 30/1380]    TRAIN loss: 3.2294
# [Iteration 35/1380]    TRAIN loss: 1.8489
# [Iteration 40/1380]    TRAIN loss: 2.7707
# [Iteration 45/1380]    TRAIN loss: 2.3355
# [Iteration 50/1380]    TRAIN loss: 3.4864
# [Iteration 55/1380]    TRAIN loss: 4.9429
# [Iteration 60/1380]    TRAIN loss: 3.3502
# [Iteration 65/1380]    TRAIN loss: 3.0649
# [Iteration 70/1380]    TRAIN loss: 2.0997
# [Iteration 75/1380]    TRAIN loss: 3.3321
# [Iteration 80/1380]    TRAIN loss: 4.7565
# [Iteration 85/1380]    TRAIN loss: 2.4128
# [Iteration 90/1380]    TRAIN loss: 2.6579
# [Iteration 95/1380]    TRAIN loss: 2.2962
# [Iteration 100/1380]    TRAIN loss: 3.0316
# [Iteration 105/1380]    TRAIN loss: 3.1910
# [Iteration 110/1380]    TRAIN loss: 2.9398
# [Iteration 115/1380]    TRAIN loss: 2.9210
# [Iteration 120/1380]    TRAIN loss: 3.4014
# [Iteration 125/1380]    TRAIN loss: 3.2939
# [Iteration 130/1380]    TRAIN loss: 2.6856
# [Iteration 135/1380]    TRAIN loss: 2.7969
# [Iteration 140/1380]    TRAIN loss: 3.2831
# [Iteration 145/1380]    TRAIN loss: 2.2017
# [Iteration 150/1380]    TRAIN loss: 3.9846
# [Iteration 155/1380]    TRAIN loss: 2.0904
# [Iteration 160/1380]    TRAIN loss: 1.5794
# [Iteration 165/1380]    TRAIN loss: 2.6892
# [Iteration 170/1380]    TRAIN loss: 3.9367
# [Iteration 175/1380]    TRAIN loss: 3.4818
# [Iteration 180/1380]    TRAIN loss: 2.1598
# [Iteration 185/1380]    TRAIN loss: 1.9661
# [Iteration 190/1380]    TRAIN loss: 3.9838
# [Iteration 195/1380]    TRAIN loss: 1.0486
# [Iteration 200/1380]    TRAIN loss: 3.6131
# [Iteration 205/1380]    TRAIN loss: 1.4166
# [Iteration 210/1380]    TRAIN loss: 3.6711
# [Iteration 215/1380]    TRAIN loss: 2.9503
# [Iteration 220/1380]    TRAIN loss: 2.6670
# [Iteration 225/1380]    TRAIN loss: 2.5913
# [Iteration 230/1380]    TRAIN loss: 2.8639
# [Iteration 235/1380]    TRAIN loss: 3.1721
# [Iteration 240/1380]    TRAIN loss: 3.4227
# [Iteration 245/1380]    TRAIN loss: 2.9552
# [Iteration 250/1380]    TRAIN loss: 2.9760
# [Iteration 255/1380]    TRAIN loss: 2.6265
# [Iteration 260/1380]    TRAIN loss: 2.5543
# [Iteration 265/1380]    TRAIN loss: 2.9334
# [Iteration 270/1380]    TRAIN loss: 2.5795
# [Iteration 275/1380]    TRAIN loss: 3.2689
# [Epoch 1/4     TRAIN acc/loss: 4387.0797/3.2689]
# [Epoch 1/4     VAL acc/loss: 29396.4068/3.3858]
# ----------
# [Iteration 0/1380]    TRAIN loss: 2.5223
# [Iteration 5/1380]    TRAIN loss: 2.4131
# [Iteration 10/1380]    TRAIN loss: 3.4311
# [Iteration 15/1380]    TRAIN loss: 2.6536
# [Iteration 20/1380]    TRAIN loss: 2.6100
# [Iteration 25/1380]    TRAIN loss: 2.5021
# [Iteration 30/1380]    TRAIN loss: 3.2910
# [Iteration 35/1380]    TRAIN loss: 2.5760
# [Iteration 40/1380]    TRAIN loss: 3.0151
# [Iteration 45/1380]    TRAIN loss: 1.9737
# [Iteration 50/1380]    TRAIN loss: 3.2570
# [Iteration 55/1380]    TRAIN loss: 2.8133
# [Iteration 60/1380]    TRAIN loss: 3.6743
# [Iteration 65/1380]    TRAIN loss: 3.0806
# [Iteration 70/1380]    TRAIN loss: 3.2265
# [Iteration 75/1380]    TRAIN loss: 2.8449
# [Iteration 80/1380]    TRAIN loss: 2.9701
# [Iteration 85/1380]    TRAIN loss: 3.6067
# [Iteration 90/1380]    TRAIN loss: 2.1423
# [Iteration 95/1380]    TRAIN loss: 3.0356
# [Iteration 100/1380]    TRAIN loss: 3.3020
# [Iteration 105/1380]    TRAIN loss: 3.3418
# [Iteration 110/1380]    TRAIN loss: 3.2993
# [Iteration 115/1380]    TRAIN loss: 3.1076
# [Iteration 120/1380]    TRAIN loss: 2.5967
# [Iteration 125/1380]    TRAIN loss: 3.0267
# [Iteration 130/1380]    TRAIN loss: 3.2391
# [Iteration 135/1380]    TRAIN loss: 2.9673
# [Iteration 140/1380]    TRAIN loss: 2.5946
# [Iteration 145/1380]    TRAIN loss: 2.8849
# [Iteration 150/1380]    TRAIN loss: 3.2968
# [Iteration 155/1380]    TRAIN loss: 2.8035
# [Iteration 160/1380]    TRAIN loss: 2.7748
# [Iteration 165/1380]    TRAIN loss: 2.1083
# [Iteration 170/1380]    TRAIN loss: 4.2459
# [Iteration 175/1380]    TRAIN loss: 2.2872
# [Iteration 180/1380]    TRAIN loss: 3.2497
# [Iteration 185/1380]    TRAIN loss: 2.3177
# [Iteration 190/1380]    TRAIN loss: 2.9126
# [Iteration 195/1380]    TRAIN loss: 3.8979
# [Iteration 200/1380]    TRAIN loss: 3.0763
# [Iteration 205/1380]    TRAIN loss: 3.3729
# [Iteration 210/1380]    TRAIN loss: 3.5419
# [Iteration 215/1380]    TRAIN loss: 3.1448
# [Iteration 220/1380]    TRAIN loss: 2.8891
# [Iteration 225/1380]    TRAIN loss: 2.1390
# [Iteration 230/1380]    TRAIN loss: 3.9369
# [Iteration 235/1380]    TRAIN loss: 3.2047
# [Iteration 240/1380]    TRAIN loss: 4.6092
# [Iteration 245/1380]    TRAIN loss: 3.7461
# [Iteration 250/1380]    TRAIN loss: 3.5090
# [Iteration 255/1380]    TRAIN loss: 3.2207
# [Iteration 260/1380]    TRAIN loss: 2.3642
# [Iteration 265/1380]    TRAIN loss: 2.9206
# [Iteration 270/1380]    TRAIN loss: 3.1246
# [Iteration 275/1380]    TRAIN loss: 2.7328
# [Epoch 2/4     TRAIN acc/loss: 6450.0616/2.7328]
# [Epoch 2/4     VAL acc/loss: 41459.6780/3.5063]
# ----------
# [Iteration 0/1380]    TRAIN loss: 3.7102
# [Iteration 5/1380]    TRAIN loss: 2.8313
# [Iteration 10/1380]    TRAIN loss: 2.9096
# [Iteration 15/1380]    TRAIN loss: 3.5143
# [Iteration 20/1380]    TRAIN loss: 3.4110
# [Iteration 25/1380]    TRAIN loss: 3.1693
# [Iteration 30/1380]    TRAIN loss: 1.6093
# [Iteration 35/1380]    TRAIN loss: 2.6206
# [Iteration 40/1380]    TRAIN loss: 2.6688
# [Iteration 45/1380]    TRAIN loss: 2.8561
# [Iteration 50/1380]    TRAIN loss: 3.8923
# [Iteration 55/1380]    TRAIN loss: 4.8330
# [Iteration 60/1380]    TRAIN loss: 2.8619
# [Iteration 65/1380]    TRAIN loss: 2.2920
# [Iteration 70/1380]    TRAIN loss: 2.6809
# [Iteration 75/1380]    TRAIN loss: 2.8901
# [Iteration 80/1380]    TRAIN loss: 3.4110
# [Iteration 85/1380]    TRAIN loss: 3.0865
# [Iteration 90/1380]    TRAIN loss: 2.8442
# [Iteration 95/1380]    TRAIN loss: 2.5821
# [Iteration 100/1380]    TRAIN loss: 2.8869
# [Iteration 105/1380]    TRAIN loss: 3.2850
# [Iteration 110/1380]    TRAIN loss: 2.9016
# [Iteration 115/1380]    TRAIN loss: 2.5650
# [Iteration 120/1380]    TRAIN loss: 3.5497
# [Iteration 125/1380]    TRAIN loss: 3.7456
# [Iteration 130/1380]    TRAIN loss: 3.4673
# [Iteration 135/1380]    TRAIN loss: 2.4676
# [Iteration 140/1380]    TRAIN loss: 3.0067
# [Iteration 145/1380]    TRAIN loss: 2.5629
# [Iteration 150/1380]    TRAIN loss: 3.2309
# [Iteration 155/1380]    TRAIN loss: 1.6957
# [Iteration 160/1380]    TRAIN loss: 0.8138
# [Iteration 165/1380]    TRAIN loss: 2.8872
# [Iteration 170/1380]    TRAIN loss: 3.1200
# [Iteration 175/1380]    TRAIN loss: 4.8425
# [Iteration 180/1380]    TRAIN loss: 4.5115
# [Iteration 185/1380]    TRAIN loss: 1.5900
# [Iteration 190/1380]    TRAIN loss: 2.9381
# [Iteration 195/1380]    TRAIN loss: 2.7388
# [Iteration 200/1380]    TRAIN loss: 2.9009
# [Iteration 205/1380]    TRAIN loss: 2.7744
# [Iteration 210/1380]    TRAIN loss: 3.3008
# [Iteration 215/1380]    TRAIN loss: 3.0377
# [Iteration 220/1380]    TRAIN loss: 2.7745
# [Iteration 225/1380]    TRAIN loss: 3.2570
# [Iteration 230/1380]    TRAIN loss: 2.7906
# [Iteration 235/1380]    TRAIN loss: 2.8534
# [Iteration 240/1380]    TRAIN loss: 2.9974
# [Iteration 245/1380]    TRAIN loss: 2.7391
# [Iteration 250/1380]    TRAIN loss: 2.8559
# [Iteration 255/1380]    TRAIN loss: 3.8852
# [Iteration 260/1380]    TRAIN loss: 3.0251
# [Iteration 265/1380]    TRAIN loss: 3.5857
# [Iteration 270/1380]    TRAIN loss: 3.0154
# [Iteration 275/1380]    TRAIN loss: 2.8198
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-e9f666c3a94d> in <module>()
#      10 solver = Solver(optim_args={"lr": 1e-4, "weight_decay": 0.001},
#      11                 loss_func=torch.nn.CrossEntropyLoss(ignore_index=-1, reduction='mean'))
# ---> 12 solver.train(model, train_loader, val_loader, log_nth=5, num_epochs=5)
#
# /content/drive/My Drive/i2dl/i2dl_colab/exercise_3/exercise_code/solver.py in train(self, model, train_loader, val_loader, num_epochs, log_nth)
#     107                 labels = labels.to(device)
#     108                 # foward pass / prediction
# --> 109                 output = model.forward(inputs)
#     110                 # loss
#     111                 val_loss = self.loss_func(output, labels)
#
# /content/drive/My Drive/i2dl/i2dl_colab/exercise_3/exercise_code/segmentation_nn.py in forward(self, x)
#      42         # x = self.model_fcn(x)
#      43         # x = self.deconv(x)
# ---> 44         x = self.model_vgg(x)
#      45         x = self.fcn(x)
#      46         x = nn.functional.upsample(x, x_inputs.size()[2:], mode='bilinear', align_corners=True).contiguous()
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     343
#     344     def forward(self, input):
# --> 345         return self.conv2d_forward(input, self.weight)
#     346
#     347 class Conv3d(_ConvNd):
#
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/conv.py in conv2d_forward(self, input, weight)
#     340                             _pair(0), self.dilation, self.groups)
#     341         return F.conv2d(input, weight, self.bias, self.stride,
# --> 342                         self.padding, self.dilation, self.groups)
#     343
#     344     def forward(self, input):
#
# RuntimeError: CUDA out of memory. Tried to allocate 20.00 MiB (GPU 0; 15.90 GiB total capacity; 14.76 GiB already allocated; 13.88 MiB free; 440.14 MiB cached)

# %% [markdown]
# # Test your Model

# %%
test_data = SegmentationData(image_paths_file='../datasets/segmentation_data_test/test.txt')
test_loader = torch.utils.data.DataLoader(test_data,
                                          batch_size=1,
                                          shuffle=False,
                                          num_workers=0)

test_scores = []
model.eval()
for inputs, targets in test_loader:
    inputs, targets = inputs.to(device), targets.to(device)
    
    outputs = model.forward(inputs)
    _, preds = torch.max(outputs, 1)
    targets_mask = targets >= 0
    test_scores.append(np.mean((preds == targets)[targets_mask].data.cpu().numpy()))
    
model.train()
np.mean(test_scores)

# %% [markdown]
# # Visualization

# %%
num_example_imgs = 4
plt.figure(figsize=(15, 5 * num_example_imgs))
for i, (img, target) in enumerate(test_data[:num_example_imgs]):
    inputs = img.unsqueeze(0)
    inputs = inputs.to(device)
    
    outputs = model.forward(inputs)
    _, preds = torch.max(outputs, 1)
    pred = preds[0].data.cpu()
    
    img, target, pred = img.numpy(), target.numpy(), pred.numpy()
    
    # img
    plt.subplot(num_example_imgs, 3, i * 3 + 1)
    plt.axis('off')
    plt.imshow(img.transpose(1, 2, 0))
    if i == 0:
        plt.title("Input image")
    
    # target
    plt.subplot(num_example_imgs, 3, i * 3 + 2)
    plt.axis('off')
    plt.imshow(label_img_to_rgb(target))
    if i == 0:
        plt.title("Target image")

    # pred
    plt.subplot(num_example_imgs, 3, i * 3 + 3)
    plt.axis('off')
    plt.imshow(label_img_to_rgb(pred))
    if i == 0:
        plt.title("Prediction image")
    
plt.show()

# %% [markdown]
# ## Visualize Filter Weights
# You can visualize the convolutional filters of the very first layer by running the following cell. The kernels should exhibit clear structures of differently oriented edges, corners and circles.

# %%
from exercise_code.vis_utils import visualize_grid

# first (next) parameter should be convolutional
conv_params = next(model.parameters()).data.cpu().numpy()
grid = visualize_grid(conv_params.transpose(0, 2, 3, 1))
plt.imshow(grid.astype('uint8'))
plt.axis('off')
plt.gcf().set_size_inches(6, 6)
plt.show()

# %% [markdown]
# ## Save the Model and Submission
#
# When you are satisfied with your training, save the model for submission. In order to be eligible for the bonus points you have to achieve an accuracy above __60%__.

# %%
os.makedirs('models', exist_ok=True)
model.save("models/segmentation_nn.model")

# %% [markdown]
# ## Possible Next Steps
#
# 1. Implement and integrate a task specific metric such as [Intersection over Union (IoU)](http://www.pyimagesearch.com/2016/11/07/intersection-over-union-iou-for-object-detection/)
# 2. Hyperparameter optimization
# 3. Data augmentation ([PyTorch tutorial](http://pytorch.org/tutorials/beginner/data_loading_tutorial.html))
